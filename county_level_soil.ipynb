# %% [markdown]
# ## Soil Data for the corn belt
#
# [https://www.nrcs.usda.gov/resources/data-and-reports/soil-survey-geographic-database-ssurgo](https://www.nrcs.usda.gov/resources/data-and-reports/soil-survey-geographic-database-ssurgo)
#
# There is a SQL database to query from called [Soil Data Access Query](https://sdmdataaccess.nrcs.usda.gov/Query.aspx). This might be a way to get tabular data to then combine with the soil and weather data.

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import requests
import os
import time

# %% [markdown]
# ## Load Yield/Weather Data

# %%
yield_weather_df = pd.read_csv('./County Corn Yield Data/corn_belt_yield_weather.csv', dtype={"fips": str})
yield_weather_df.head()
# Out:
#   state_name state_alpha  state_ansi  county_ansi   fips county_name  year  \
# 0   ILLINOIS          IL          17           11  17011      BUREAU  2025
# 1   ILLINOIS          IL          17           11  17011      BUREAU  2024
# 2   ILLINOIS          IL          17           11  17011      BUREAU  2023
# 3   ILLINOIS          IL          17           11  17011      BUREAU  2022
# 4   ILLINOIS          IL          17           11  17011      BUREAU  2021
#
#                                    short_desc  unit_desc statisticcat_desc  \
# 0  CORN, GRAIN - YIELD, MEASURED IN BU / ACRE  BU / ACRE             YIELD
# 1  CORN, GRAIN - YIELD, MEASURED IN BU / ACRE  BU / ACRE             YIELD
# 2  CORN, GRAIN - YIELD, MEASURED IN BU / ACRE  BU / ACRE             YIELD
# 3  CORN, GRAIN - YIELD, MEASURED IN BU / ACRE  BU / ACRE             YIELD
# 4  CORN, GRAIN - YIELD, MEASURED IN BU / ACRE  BU / ACRE             YIELD
#
#    ...  vp_mean_pa_m03  vp_mean_pa_m04  vp_mean_pa_m05  vp_mean_pa_m06  \
# 0  ...      669.014194      860.098667     1149.159032     1970.153333
# 1  ...      652.787419      916.069000     1400.653548     1984.589000
# 2  ...      551.773226      786.947000     1208.501613     1535.258667
# 3  ...      561.575484      759.192000     1471.162581     1827.592333
# 4  ...      594.198387      847.325333     1287.721935     2010.488000
#
#    vp_mean_pa_m07  vp_mean_pa_m08  vp_mean_pa_m09  vp_mean_pa_m10  \
# 0     2279.072258     1885.761613     1442.058333     1146.211935
# 1     1915.040968     1906.293871     1466.279667      978.475806
# 2     1945.164194     1912.132581     1583.150333     1067.424516
# 3     2026.516452     1920.243871     1510.500333      831.142258
# 4     2090.430323     2056.888065     1548.647000     1280.342903
#
#    vp_mean_pa_m11  vp_mean_pa_m12
# 0      628.067667      357.549355
# 1      777.935667      462.975000
# 2      567.281000      614.017097
# 3      627.178667      393.786774
# 4      565.100000      504.136452
#
# [5 rows x 97 columns]

# %% [markdown]
# ## Checking Data

# %%
yield_weather_df.shape
# Out:
# (24644, 97)

# %%
yield_weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24644 entries, 0 to 24643
# Data columns (total 97 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   state_name                 24644 non-null  object
#  1   state_alpha                24644 non-null  object
#  2   state_ansi                 24644 non-null  int64
#  3   county_ansi                24644 non-null  int64
#  4   fips                       24644 non-null  object
#  5   county_name                24644 non-null  object
#  6   year                       24644 non-null  int64
#  7   short_desc                 24644 non-null  object
#  8   unit_desc                  24644 non-null  object
#  9   statisticcat_desc          24644 non-null  object
#  10  Value                      24644 non-null  float64
#  11  latitude                   24644 non-null  float64
#  12  longitude                  24644 non-null  float64
#  13  prcp_total_mm_m01          24644 non-null  float64
#  14  prcp_total_mm_m02          24644 non-null  float64
#  15  prcp_total_mm_m03          24644 non-null  float64
#  16  prcp_total_mm_m04          24644 non-null  float64
#  17  prcp_total_mm_m05          24644 non-null  float64
#  18  prcp_total_mm_m06          24644 non-null  float64
#  19  prcp_total_mm_m07          24644 non-null  float64
#  20  prcp_total_mm_m08          24644 non-null  float64
#  21  prcp_total_mm_m09          24644 non-null  float64
#  22  prcp_total_mm_m10          24644 non-null  float64
#  23  prcp_total_mm_m11          24644 non-null  float64
#  24  prcp_total_mm_m12          24644 non-null  float64
#  25  radiation_total_mj_m2_m01  24644 non-null  float64
#  26  radiation_total_mj_m2_m02  24644 non-null  float64
#  27  radiation_total_mj_m2_m03  24644 non-null  float64
#  28  radiation_total_mj_m2_m04  24644 non-null  float64
#  29  radiation_total_mj_m2_m05  24644 non-null  float64
#  30  radiation_total_mj_m2_m06  24644 non-null  float64
#  31  radiation_total_mj_m2_m07  24644 non-null  float64
#  32  radiation_total_mj_m2_m08  24644 non-null  float64
#  33  radiation_total_mj_m2_m09  24644 non-null  float64
#  34  radiation_total_mj_m2_m10  24644 non-null  float64
#  35  radiation_total_mj_m2_m11  24644 non-null  float64
#  36  radiation_total_mj_m2_m12  24644 non-null  float64
#  37  dayl_mean_s_m01            24644 non-null  float64
#  38  dayl_mean_s_m02            24644 non-null  float64
#  39  dayl_mean_s_m03            24644 non-null  float64
#  40  dayl_mean_s_m04            24644 non-null  float64
#  41  dayl_mean_s_m05            24644 non-null  float64
#  42  dayl_mean_s_m06            24644 non-null  float64
#  43  dayl_mean_s_m07            24644 non-null  float64
#  44  dayl_mean_s_m08            24644 non-null  float64
#  45  dayl_mean_s_m09            24644 non-null  float64
#  46  dayl_mean_s_m10            24644 non-null  float64
#  47  dayl_mean_s_m11            24644 non-null  float64
#  48  dayl_mean_s_m12            24644 non-null  float64
#  49  swe_mean_kg_m2_m01         24644 non-null  float64
#  50  swe_mean_kg_m2_m02         24644 non-null  float64
#  51  swe_mean_kg_m2_m03         24644 non-null  float64
#  52  swe_mean_kg_m2_m04         24644 non-null  float64
#  53  swe_mean_kg_m2_m05         24644 non-null  float64
#  54  swe_mean_kg_m2_m06         24644 non-null  float64
#  55  swe_mean_kg_m2_m07         24644 non-null  float64
#  56  swe_mean_kg_m2_m08         24644 non-null  float64
#  57  swe_mean_kg_m2_m09         24644 non-null  float64
#  58  swe_mean_kg_m2_m10         24644 non-null  float64
#  59  swe_mean_kg_m2_m11         24644 non-null  float64
#  60  swe_mean_kg_m2_m12         24644 non-null  float64
#  61  tmax_mean_c_m01            24644 non-null  float64
#  62  tmax_mean_c_m02            24644 non-null  float64
#  63  tmax_mean_c_m03            24644 non-null  float64
#  64  tmax_mean_c_m04            24644 non-null  float64
#  65  tmax_mean_c_m05            24644 non-null  float64
#  66  tmax_mean_c_m06            24644 non-null  float64
#  67  tmax_mean_c_m07            24644 non-null  float64
#  68  tmax_mean_c_m08            24644 non-null  float64
#  69  tmax_mean_c_m09            24644 non-null  float64
#  70  tmax_mean_c_m10            24644 non-null  float64
#  71  tmax_mean_c_m11            24644 non-null  float64
#  72  tmax_mean_c_m12            24644 non-null  float64
#  73  tmin_mean_c_m01            24644 non-null  float64
#  74  tmin_mean_c_m02            24644 non-null  float64
#  75  tmin_mean_c_m03            24644 non-null  float64
#  76  tmin_mean_c_m04            24644 non-null  float64
#  77  tmin_mean_c_m05            24644 non-null  float64
#  78  tmin_mean_c_m06            24644 non-null  float64
#  79  tmin_mean_c_m07            24644 non-null  float64
#  80  tmin_mean_c_m08            24644 non-null  float64
#  81  tmin_mean_c_m09            24644 non-null  float64
#  82  tmin_mean_c_m10            24644 non-null  float64
#  83  tmin_mean_c_m11            24644 non-null  float64
#  84  tmin_mean_c_m12            24644 non-null  float64
#  85  vp_mean_pa_m01             24644 non-null  float64
#  86  vp_mean_pa_m02             24644 non-null  float64
#  87  vp_mean_pa_m03             24644 non-null  float64
#  88  vp_mean_pa_m04             24644 non-null  float64
#  89  vp_mean_pa_m05             24644 non-null  float64
#  90  vp_mean_pa_m06             24644 non-null  float64
#  91  vp_mean_pa_m07             24644 non-null  float64
#  92  vp_mean_pa_m08             24644 non-null  float64
#  93  vp_mean_pa_m09             24644 non-null  float64
#  94  vp_mean_pa_m10             24644 non-null  float64
#  95  vp_mean_pa_m11             24644 non-null  float64
#  96  vp_mean_pa_m12             24644 non-null  float64
# dtypes: float64(87), int64(3), object(7)
# memory usage: 18.2+ MB

# %%
yield_weather_df.describe()
# Out:
#          state_ansi   county_ansi          year         Value      latitude  \
# count  24644.000000  24644.000000  24644.000000  24644.000000  24644.000000
# mean      28.079127     93.939012   2011.815533    147.829005     41.299657
# std       10.878044     57.255843      7.443268     38.241255      2.812696
# min       17.000000      1.000000   2000.000000      0.000000     36.211400
# 25%       19.000000     45.000000   2005.000000    124.000000     39.059800
# 50%       26.000000     91.000000   2011.000000    151.800000     40.988000
# 75%       31.000000    139.000000   2018.000000    175.300000     43.345900
# max       55.000000    239.000000   2025.000000    253.600000     48.814900
#
#           longitude  prcp_total_mm_m01  prcp_total_mm_m02  prcp_total_mm_m03  \
# count  24644.000000       24644.000000       24644.000000       24644.000000
# mean     -91.543901          46.268875          48.823535          68.422388
# std        5.702835          42.391356          43.909309          47.886767
# min     -103.846600           0.000000           0.000000           0.000000
# 25%      -96.177900          14.850000          17.707500          32.010000
# 50%      -91.479300          32.025000          36.840000          60.490000
# 75%      -86.446200          66.360000          66.080000          93.090000
# max      -80.748200         283.480000         343.800000         444.310000
#
#        prcp_total_mm_m04  ...  vp_mean_pa_m03  vp_mean_pa_m04  vp_mean_pa_m05  \
# count       24644.000000  ...    24644.000000    24644.000000    24644.000000
# mean           95.190592  ...      522.005559      757.236564     1199.100607
# std            54.840617  ...      200.292134      246.988560      290.578833
# min             0.000000  ...       84.043548      153.379333      263.736774
# 25%            57.330000  ...      372.631452      585.783167     1008.830806
# 50%            87.870000  ...      511.394677      767.745500     1211.288548
# 75%           121.957500  ...      655.682581      934.913667     1405.645242
# max           493.550000  ...     1306.850000     1517.362333     2163.205806
#
#        vp_mean_pa_m06  vp_mean_pa_m07  vp_mean_pa_m08  vp_mean_pa_m09  \
# count    24644.000000    24644.000000    24644.000000    24644.000000
# mean      1731.095781     2000.412277     1874.845454     1438.836336
# std        298.289660      299.680529      282.811489      237.267583
# min        463.626667      612.769032      589.784516      388.617667
# 25%       1548.044583     1802.153790     1684.873952     1285.802917
# 50%       1746.882167     2003.823226     1859.227742     1439.530833
# 75%       1936.222333     2206.897661     2068.388629     1595.977167
# max       2737.994667     2947.784839     2712.901935     2299.902667
#
#        vp_mean_pa_m10  vp_mean_pa_m11  vp_mean_pa_m12
# count    24644.000000    24644.000000    24644.000000
# mean       933.330077      601.022181      414.921826
# std        183.342283      142.148487      136.477327
# min        258.033548      186.626667       88.901667
# 25%        802.756048      494.868000      315.487581
# 50%        926.538226      594.222500      402.797419
# 75%       1052.381532      703.052333      505.692911
# max       1532.883548     1123.550667      940.150323
#
# [8 rows x 90 columns]

# %%
yield_weather_df.describe(include='object')
# Out:
#        state_name state_alpha   fips county_name  \
# count       24644       24644  24644       24644
# unique         13          13   1124         704
# top          IOWA          IA  17011     JACKSON
# freq         2470        2470     26         231
#
#                                         short_desc  unit_desc  \
# count                                        24644      24644
# unique                                           1          1
# top     CORN, GRAIN - YIELD, MEASURED IN BU / ACRE  BU / ACRE
# freq                                         24644      24644
#
#        statisticcat_desc
# count              24644
# unique                 1
# top                YIELD
# freq               24644

# %%
yield_weather_df.isnull().sum()
# Out:
# state_name        0
# state_alpha       0
# state_ansi        0
# county_ansi       0
# fips              0
#                  ..
# vp_mean_pa_m08    0
# vp_mean_pa_m09    0
# vp_mean_pa_m10    0
# vp_mean_pa_m11    0
# vp_mean_pa_m12    0
# Length: 97, dtype: int64

# %%
yield_weather_df.duplicated().sum()
# Out:
# 0

# %%
for i in yield_weather_df.select_dtypes(include='object').columns:
    print(yield_weather_df[i].value_counts())
    print("*"*30)
# Out:
# state_name
# IOWA            2470
# ILLINOIS        2417
# INDIANA         2142
# KENTUCKY        2092
# KANSAS          2090
# NEBRASKA        2069
# OHIO            2051
# MISSOURI        1967
# MINNESOTA       1867
# WISCONSIN       1577
# MICHIGAN        1485
# SOUTH DAKOTA    1363
# NORTH DAKOTA    1054
# Name: count, dtype: int64
# ******************************
# state_alpha
# IA    2470
# IL    2417
# IN    2142
# KY    2092
# KS    2090
# NE    2069
# OH    2051
# MO    1967
# MN    1867
# WI    1577
# MI    1485
# SD    1363
# ND    1054
# Name: count, dtype: int64
# ******************************
# fips
# 17011    26
# 27169    26
# 26161    26
# 26147    26
# 26115    26
#          ..
# 29055     1
# 29119     1
# 29229     1
# 29209     1
# 21189     1
# Name: count, Length: 1124, dtype: int64
# ******************************
# county_name
# JACKSON       231
# WASHINGTON    217
# JEFFERSON     199
# CLAY          196
# MONROE        184
#              ...
# MAGOFFIN        1
# STONE           1
# DENT            1
# OWSLEY          1
# ELLIOTT         1
# Name: count, Length: 704, dtype: int64
# ******************************
# short_desc
# CORN, GRAIN - YIELD, MEASURED IN BU / ACRE    24644
# Name: count, dtype: int64
# ******************************
# unit_desc
# BU / ACRE    24644
# Name: count, dtype: int64
# ******************************
# statisticcat_desc
# YIELD    24644
# Name: count, dtype: int64
# ******************************

# %% [markdown]
# ## Make one row per county
#
# Soil data does not change between the years. So, to not query the soil data access as much, we will just do each county once

# %%
county_locations = yield_weather_df[["fips", "state_alpha", "county_name"]].drop_duplicates("fips").reset_index(drop=True)

# %%
county_locations.shape
# Out:
# (1124, 3)

# %%
county_locations.head()
# Out:
#     fips state_alpha county_name
# 0  17011          IL      BUREAU
# 1  17015          IL     CARROLL
# 2  17073          IL       HENRY
# 3  17085          IL  JO DAVIESS
# 4  17103          IL         LEE

# %% [markdown]
# ## Get Soil Data
#
# The soil data are downloaded from the USDA Soil Data Access service.
#
# SSURGO organizes soil data into several levels:
#
# 1. A county contains multiple soil map units.
# 2. A map unit can contain multiple soil components.
# 3. A component can contain multiple soil layers, called horizons.
#
# The query collects the map units, components, horizons, and soil measurements
# needed to calculate representative county values.
#
# The data are downloaded one county at a time. Each county is saved as a
# separate CSV file so the download can be restarted without downloading every
# county again.

# %%
SDA_URL = "https://SDMDataAccess.sc.egov.usda.gov/Tabular/post.rest"

# %%
# Make directory to save each of the soil files in
os.makedirs("soil_counties", exist_ok=True)

# %% [markdown]
# ### Important Parts of the Soil Query
#
# The query uses:
#
# - `county_mapunit_acres` to measure how much of each map unit is inside the
#   county.
# - `comppct_r` to measure how common each soil component is within its map unit.
# - `hzdept_r` and `hzdepb_r` to identify the top and bottom of each soil layer.
# - Soil-property columns such as sand, clay, organic matter, pH, and bulk
#   density.
#
# Only soil horizons that overlap the upper 30 centimeters are selected.

# %%
for index, row in county_locations.iterrows():

    # The SDA uses the county intiial (Ex: IN) and the last 3 of fips code
    county_symbol = row["state_alpha"] + row["fips"][-3:]

    county_file = f"soil_counties/soil_{row["fips"]}.csv"

    if os.path.exists(county_file):
        print(f"{index}/{len(county_locations)}: {row["fips"]} already completed")
        continue

    print(f"Downloading county {index + 1} of {len(county_locations)}:", row["state_alpha"], row["fips"], county_symbol)

    query = f"""
    SELECT
        lo.areasymbol AS county_symbol,
        muao.mukey,
        muao.areaovacres AS county_mapunit_acres,
        mua.aws0100wta,
        mua.slopegradwta,
        co.comppct_r,
        ch.hzdept_r,
        ch.hzdepb_r,
        ch.sandtotal_r,
        ch.silttotal_r,
        ch.claytotal_r,
        ch.om_r,
        ch.ph1to1h2o_r,
        ch.dbthirdbar_r,
        ch.ksat_r
    
    FROM laoverlap AS lo
    
    INNER JOIN muaoverlap AS muao
        ON lo.lareaovkey = muao.lareaovkey
    
    INNER JOIN mapunit AS mu
        ON muao.mukey = mu.mukey
    
    LEFT JOIN muaggatt AS mua
        ON muao.mukey = mua.mukey
    
    INNER JOIN component AS co
        ON muao.mukey = co.mukey
    
    INNER JOIN chorizon AS ch
        ON co.cokey = ch.cokey
    
    WHERE
        lo.areatypename = 'County or Parish'
        AND lo.areasymbol = '{county_symbol}'
        AND ch.hzdept_r < 30
        AND ch.hzdepb_r > 0
    """

    parameters = {
        "query": query,
        "format": "JSON+COLUMNNAME"
    }

    try:

        response = requests.post(
            SDA_URL,
            json=parameters,
            timeout=120
        )

        response.raise_for_status()

        soil_json = response.json()

        columns = soil_json["Table"][0]
        rows = soil_json["Table"][1:]

        soil_data = pd.DataFrame(rows, columns=columns)

        soil_data["fips"] = row["fips"]

        soil_data.to_csv(
            county_file,
            index=False
        )

        print("Saved")

    except Exception as error:

        print("Failed:", row["fips"], error)

    time.sleep(0.1)
# Out:
# 0/1124: 17011 already completed
# 1/1124: 17015 already completed
# 2/1124: 17073 already completed
# 3/1124: 17085 already completed
# 4/1124: 17103 already completed
# 5/1124: 17131 already completed
# 6/1124: 17141 already completed
# 7/1124: 17155 already completed
# 8/1124: 17161 already completed
# 9/1124: 17177 already completed
# 10/1124: 17195 already completed
# 11/1124: 17201 already completed
# 12/1124: 17007 already completed
# 13/1124: 17031 already completed
# 14/1124: 17037 already completed
# 15/1124: 17043 already completed
# 16/1124: 17063 already completed
# 17/1124: 17089 already completed
# 18/1124: 17093 already completed
# 19/1124: 17097 already completed
# 20/1124: 17099 already completed
# 21/1124: 17111 already completed
# 22/1124: 17197 already completed
# 23/1124: 17001 already completed
# 24/1124: 17009 already completed
# 25/1124: 17057 already completed
# 26/1124: 17067 already completed
# 27/1124: 17071 already completed
# 28/1124: 17095 already completed
# 29/1124: 17109 already completed
# 30/1124: 17169 already completed
# 31/1124: 17187 already completed
# 32/1124: 17039 already completed
# 33/1124: 17107 already completed
# 34/1124: 17113 already completed
# 35/1124: 17115 already completed
# 36/1124: 17123 already completed
# 37/1124: 17125 already completed
# 38/1124: 17129 already completed
# 39/1124: 17143 already completed
# 40/1124: 17175 already completed
# 41/1124: 17179 already completed
# 42/1124: 17203 already completed
# 43/1124: 17019 already completed
# 44/1124: 17053 already completed
# 45/1124: 17075 already completed
# 46/1124: 17091 already completed
# 47/1124: 17105 already completed
# 48/1124: 17147 already completed
# 49/1124: 17183 already completed
# 50/1124: 17005 already completed
# 51/1124: 17013 already completed
# 52/1124: 17017 already completed
# 53/1124: 17021 already completed
# 54/1124: 17061 already completed
# 55/1124: 17083 already completed
# 56/1124: 17117 already completed
# 57/1124: 17119 already completed
# 58/1124: 17135 already completed
# 59/1124: 17137 already completed
# 60/1124: 17149 already completed
# 61/1124: 17167 already completed
# 62/1124: 17171 already completed
# 63/1124: 17023 already completed
# 64/1124: 17025 already completed
# 65/1124: 17029 already completed
# 66/1124: 17033 already completed
# 67/1124: 17035 already completed
# 68/1124: 17041 already completed
# 69/1124: 17045 already completed
# 70/1124: 17049 already completed
# 71/1124: 17051 already completed
# 72/1124: 17079 already completed
# 73/1124: 17101 already completed
# 74/1124: 17121 already completed
# 75/1124: 17139 already completed
# 76/1124: 17159 already completed
# 77/1124: 17173 already completed
# 78/1124: 17003 already completed
# 79/1124: 17027 already completed
# 80/1124: 17077 already completed
# 81/1124: 17087 already completed
# 82/1124: 17133 already completed
# 83/1124: 17145 already completed
# 84/1124: 17153 already completed
# 85/1124: 17157 already completed
# 86/1124: 17163 already completed
# 87/1124: 17181 already completed
# 88/1124: 17189 already completed
# 89/1124: 17199 already completed
# 90/1124: 17047 already completed
# 91/1124: 17055 already completed
# 92/1124: 17059 already completed
# 93/1124: 17065 already completed
# 94/1124: 17069 already completed
# 95/1124: 17081 already completed
# 96/1124: 17127 already completed
# 97/1124: 17151 already completed
# 98/1124: 17165 already completed
# 99/1124: 17185 already completed
# 100/1124: 17191 already completed
# 101/1124: 17193 already completed
# 102/1124: 18007 already completed
# 103/1124: 18073 already completed
# 104/1124: 18089 already completed
# 105/1124: 18091 already completed
# 106/1124: 18111 already completed
# 107/1124: 18127 already completed
# 108/1124: 18131 already completed
# 109/1124: 18149 already completed
# 110/1124: 18181 already completed
# 111/1124: 18015 already completed
# 112/1124: 18017 already completed
# 113/1124: 18039 already completed
# 114/1124: 18049 already completed
# 115/1124: 18085 already completed
# 116/1124: 18099 already completed
# 117/1124: 18103 already completed
# 118/1124: 18141 already completed
# 119/1124: 18169 already completed
# 120/1124: 18001 already completed
# 121/1124: 18003 already completed
# 122/1124: 18033 already completed
# 123/1124: 18069 already completed
# 124/1124: 18087 already completed
# 125/1124: 18113 already completed
# 126/1124: 18151 already completed
# 127/1124: 18179 already completed
# 128/1124: 18183 already completed
# 129/1124: 18021 already completed
# 130/1124: 18045 already completed
# 131/1124: 18107 already completed
# 132/1124: 18119 already completed
# 133/1124: 18121 already completed
# 134/1124: 18133 already completed
# 135/1124: 18157 already completed
# 136/1124: 18165 already completed
# 137/1124: 18167 already completed
# 138/1124: 18171 already completed
# 139/1124: 18005 already completed
# 140/1124: 18011 already completed
# 141/1124: 18023 already completed
# 142/1124: 18031 already completed
# 143/1124: 18053 already completed
# 144/1124: 18057 already completed
# 145/1124: 18059 already completed
# 146/1124: 18063 already completed
# 147/1124: 18067 already completed
# 148/1124: 18081 already completed
# 149/1124: 18095 already completed
# 150/1124: 18097 already completed
# 151/1124: 18109 already completed
# 152/1124: 18139 already completed
# 153/1124: 18145 already completed
# 154/1124: 18159 already completed
# 155/1124: 18009 already completed
# 156/1124: 18035 already completed
# 157/1124: 18041 already completed
# 158/1124: 18065 already completed
# 159/1124: 18075 already completed
# 160/1124: 18135 already completed
# 161/1124: 18161 already completed
# 162/1124: 18177 already completed
# 163/1124: 18027 already completed
# 164/1124: 18037 already completed
# 165/1124: 18051 already completed
# 166/1124: 18055 already completed
# 167/1124: 18083 already completed
# 168/1124: 18101 already completed
# 169/1124: 18125 already completed
# 170/1124: 18129 already completed
# 171/1124: 18147 already completed
# 172/1124: 18153 already completed
# 173/1124: 18163 already completed
# 174/1124: 18173 already completed
# 175/1124: 18013 already completed
# 176/1124: 18025 already completed
# 177/1124: 18043 already completed
# 178/1124: 18061 already completed
# 179/1124: 18071 already completed
# 180/1124: 18093 already completed
# 181/1124: 18105 already completed
# 182/1124: 18117 already completed
# 183/1124: 18123 already completed
# 184/1124: 18175 already completed
# 185/1124: 18019 already completed
# 186/1124: 18029 already completed
# 187/1124: 18047 already completed
# 188/1124: 18077 already completed
# 189/1124: 18079 already completed
# 190/1124: 18115 already completed
# 191/1124: 18137 already completed
# 192/1124: 18143 already completed
# 193/1124: 18155 already completed
# 296/1124: 20137 already completed
# 297/1124: 20153 already completed
# 298/1124: 20179 already completed
# 299/1124: 20181 already completed
# 300/1124: 20193 already completed
# 301/1124: 20063 already completed
# 302/1124: 20071 already completed
# 303/1124: 20101 already completed
# 304/1124: 20109 already completed
# 305/1124: 20135 already completed
# 306/1124: 20171 already completed
# 307/1124: 20195 already completed
# 308/1124: 20199 already completed
# 309/1124: 20203 already completed
# 310/1124: 20025 already completed
# 311/1124: 20055 already completed
# 312/1124: 20057 already completed
# 313/1124: 20067 already completed
# 314/1124: 20069 already completed
# 315/1124: 20075 already completed
# 316/1124: 20081 already completed
# 317/1124: 20083 already completed
# 318/1124: 20093 already completed
# 319/1124: 20119 already completed
# 320/1124: 20129 already completed
# 321/1124: 20175 already completed
# 322/1124: 20187 already completed
# 323/1124: 20189 already completed
# 324/1124: 20027 already completed
# 325/1124: 20029 already completed
# 326/1124: 20089 already completed
# 327/1124: 20123 already completed
# 328/1124: 20141 already completed
# 329/1124: 20143 already completed
# 330/1124: 20147 already completed
# 331/1124: 20157 already completed
# 332/1124: 20163 already completed
# 333/1124: 20183 already completed
# 334/1124: 20201 already completed
# 335/1124: 20009 already completed
# 336/1124: 20041 already completed
# 337/1124: 20051 already completed
# 338/1124: 20053 already completed
# 339/1124: 20105 already completed
# 340/1124: 20113 already completed
# 341/1124: 20115 already completed
# 342/1124: 20159 already completed
# 343/1124: 20165 already completed
# 344/1124: 20167 already completed
# 345/1124: 20169 already completed
# 346/1124: 20007 already completed
# 347/1124: 20033 already completed
# 348/1124: 20047 already completed
# 349/1124: 20077 already completed
# 350/1124: 20079 already completed
# 351/1124: 20095 already completed
# 352/1124: 20097 already completed
# 353/1124: 20145 already completed
# 354/1124: 20151 already completed
# 355/1124: 20155 already completed
# 356/1124: 20173 already completed
# 357/1124: 20185 already completed
# 358/1124: 20191 already completed
# 359/1124: 20005 already completed
# 360/1124: 20013 already completed
# 361/1124: 20043 already completed
# 362/1124: 20085 already completed
# 363/1124: 20087 already completed
# 364/1124: 20103 already completed
# 365/1124: 20117 already completed
# 366/1124: 20131 already completed
# 367/1124: 20149 already completed
# 368/1124: 20161 already completed
# 369/1124: 20209 already completed
# 370/1124: 20003 already completed
# 371/1124: 20017 already completed
# 372/1124: 20031 already completed
# 373/1124: 20045 already completed
# 374/1124: 20059 already completed
# 375/1124: 20061 already completed
# 376/1124: 20091 already completed
# 377/1124: 20107 already completed
# 378/1124: 20111 already completed
# 379/1124: 20121 already completed
# 380/1124: 20127 already completed
# 381/1124: 20139 already completed
# 382/1124: 20177 already completed
# 383/1124: 20197 already completed
# 384/1124: 20001 already completed
# 385/1124: 20011 already completed
# 386/1124: 20015 already completed
# 387/1124: 20019 already completed
# 388/1124: 20021 already completed
# 389/1124: 20035 already completed
# 390/1124: 20037 already completed
# 391/1124: 20049 already completed
# 392/1124: 20073 already completed
# 393/1124: 20099 already completed
# 394/1124: 20125 already completed
# 395/1124: 20133 already completed
# 396/1124: 20205 already completed
# 397/1124: 20207 already completed
# 1105/1124: 55043 already completed
# 1106/1124: 55049 already completed
# 1107/1124: 55065 already completed
# 1108/1124: 55103 already completed
# 1109/1124: 55111 already completed
# 1110/1124: 55123 already completed
# 1111/1124: 55021 already completed
# 1112/1124: 55025 already completed
# 1113/1124: 55027 already completed
# 1114/1124: 55045 already completed
# 1115/1124: 55055 already completed
# 1116/1124: 55105 already completed
# 1117/1124: 55059 already completed
# 1118/1124: 55079 already completed
# 1119/1124: 55089 already completed
# 1120/1124: 55101 already completed
# 1121/1124: 55127 already completed
# 1122/1124: 55131 already completed
# 1123/1124: 55133 already completed

# %% [markdown]
# ## Combine all of the soil data files

# %%
temp = pd.read_csv('soil_counties/soil_17001.csv')

# %%
temp.head()
# Out:
#   county_symbol    mukey  county_mapunit_acres  aws0100wta  slopegradwta  \
# 0         IL001  2378631                  6345       22.94           7.5
# 1         IL001  2378631                  6345       22.94           7.5
# 2         IL001  2378632                   753       12.36          14.0
# 3         IL001  2378632                   753       12.36          14.0
# 4         IL001  2378632                   753       12.36          14.0
#
#    comppct_r  hzdept_r  hzdepb_r  sandtotal_r  silttotal_r  claytotal_r  om_r  \
# 0       90.0         0        18          4.0         73.0         23.0  2.50
# 1       90.0        18        94          4.0         65.0         31.0  0.25
# 2       94.0         0        13          8.0         69.0         23.0  2.00
# 3       94.0        13        75          8.0         58.0         34.0  0.25
# 4        2.0        15        67         33.0         37.0         30.0  0.60
#
#    ph1to1h2o_r  dbthirdbar_r  ksat_r   fips
# 0          6.2          1.45    9.17  17001
# 1          5.8          1.50    9.17  17001
# 2          5.8          1.42    9.17  17001
# 3          5.0          1.47    0.91  17001
# 4          5.9          1.49    9.17  17001

# %%
all_soil_data = []

for filename in os.listdir("soil_counties"):
    if filename.endswith(".csv"):
        try:
            data = pd.read_csv(f"soil_counties/{filename}", dtype={"fips": str, "mukey":str})
            all_soil_data.append(data)
        except pd.errors.EmptyDataError:
            df = pd.DataFrame()  # Fallback to an empty DataFrame

# %%
soil_raw_df = pd.concat(all_soil_data, ignore_index=True)
soil_raw_df.head()
# Out:
#   county_symbol   mukey  county_mapunit_acres  aws0100wta  slopegradwta  \
# 0         OH119  537849                1215.0       13.08           5.4
# 1         OH119  537849                1215.0       13.08           5.4
# 2         OH119  537849                1215.0       13.08           5.4
# 3         OH119  537849                1215.0       13.08           5.4
# 4         OH119  537849                1215.0       13.08           5.4
#
#    comppct_r  hzdept_r  hzdepb_r  sandtotal_r  silttotal_r  claytotal_r  om_r  \
# 0        5.0         0         8         13.0         67.0         20.0   3.0
# 1        5.0        15        28          7.0         67.0         26.0   1.0
# 2        5.0         8        15         11.0         69.0         20.0   2.0
# 3        5.0        28        81         15.0         52.0         33.0   0.5
# 4        5.0         0        11         16.0         70.0         14.0   3.9
#
#    ph1to1h2o_r  dbthirdbar_r  ksat_r   fips
# 0          5.7          1.38    9.17  39119
# 1          5.2          1.37    9.17  39119
# 2          5.0          1.39    9.17  39119
# 3          5.1          1.50    2.70  39119
# 4          4.7          1.20    9.17  39119

# %%
soil_raw_df.tail()
# Out:
#        county_symbol   mukey  county_mapunit_acres  aws0100wta  slopegradwta  \
# 715666         KY029  550964                 873.0       11.85           4.0
# 715667         KY029  550964                 873.0       11.85           4.0
# 715668         KY029  550964                 873.0       11.85           4.0
# 715669         KY029  550964                 873.0       11.85           4.0
# 715670         KY029  550964                 873.0       11.85           4.0
#
#         comppct_r  hzdept_r  hzdepb_r  sandtotal_r  silttotal_r  claytotal_r  \
# 715666        5.0        20        71          7.0         67.0         26.0
# 715667        5.0         0        15         12.0         58.0         30.0
# 715668        5.0        15        46         10.0         42.0         48.0
# 715669       85.0         0        18         15.0         63.0         22.0
# 715670       85.0        18        74          7.0         48.0         45.0
#
#         om_r  ph1to1h2o_r  dbthirdbar_r  ksat_r   fips
# 715666  0.75          5.5          1.42    9.00  21029
# 715667  1.75          7.0          1.48    0.92  21029
# 715668  0.25          8.2          1.53    0.92  21029
# 715669  2.25          6.7          1.30    9.11  21029
# 715670  0.30          5.8          1.43    0.55  21029

# %%
soil_raw_df.columns
# Out:
# Index(['county_symbol', 'mukey', 'county_mapunit_acres', 'aws0100wta',
#        'slopegradwta', 'comppct_r', 'hzdept_r', 'hzdepb_r', 'sandtotal_r',
#        'silttotal_r', 'claytotal_r', 'om_r', 'ph1to1h2o_r', 'dbthirdbar_r',
#        'ksat_r', 'fips'],
#       dtype='object')

# %%
soil_raw_df.shape
# Out:
# (715671, 16)

# %%
soil_raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 715671 entries, 0 to 715670
# Data columns (total 16 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   county_symbol         715671 non-null  object
#  1   mukey                 715671 non-null  object
#  2   county_mapunit_acres  715638 non-null  float64
#  3   aws0100wta            715344 non-null  float64
#  4   slopegradwta          715542 non-null  float64
#  5   comppct_r             714271 non-null  float64
#  6   hzdept_r              715671 non-null  int64
#  7   hzdepb_r              715671 non-null  int64
#  8   sandtotal_r           697583 non-null  float64
#  9   silttotal_r           697225 non-null  float64
#  10  claytotal_r           700662 non-null  float64
#  11  om_r                  712197 non-null  float64
#  12  ph1to1h2o_r           701376 non-null  float64
#  13  dbthirdbar_r          711878 non-null  float64
#  14  ksat_r                715399 non-null  float64
#  15  fips                  715671 non-null  object
# dtypes: float64(11), int64(2), object(3)
# memory usage: 87.4+ MB

# %% [markdown]
# ## Calculate Soil-Layer Thickness
#
# Some soil layers extend below 30 cm. This project uses only the portion of each
# layer that falls between 0 and 30 cm.
#
# For example:
#
# - A layer from 0–10 cm contributes 10 cm.
# - A layer from 10–40 cm contributes 20 cm because only the 10–30 cm portion is
#   used.
# - A layer beginning below 30 cm is not included.
#
# This makes sure the final values represent the upper 30 cm of soil.

# %%
soil_raw_df["top_cm"] = (soil_raw_df["hzdept_r"].clip(lower=0, upper=30))

# %%
soil_raw_df["bottom_cm"] = (soil_raw_df["hzdepb_r"].clip(lower=0,upper=30))

# %%
soil_raw_df["thickness_cm"] = (soil_raw_df["bottom_cm"] - soil_raw_df["top_cm"]).clip(lower=0)

# %% [markdown]
# ## Calculate the Soil Weight
#
# The soil rows should not all contribute equally. Some represent more land,
# more common soil components, or thicker soil layers.
#
# The weight is calculated using:
#
# $$
# \text{soil weight}
# =
# \text{county map-unit acres}
# \times
# \frac{\text{component percent}}{100}
# \times
# \text{layer thickness}
# $$
#
# This gives more influence to soil records that represent a larger portion of
# the county's upper 30 cm of soil.

# %%
soil_raw_df["soil_weight"] = (soil_raw_df["county_mapunit_acres"] * (soil_raw_df["comppct_r"] / 100) * soil_raw_df["thickness_cm"])

# %% [markdown]
# ## Soil Properties
#
# The following soil properties are calculated for each county:
#
# | Property | Simple meaning |
# |---|---|
# | Sand | Larger soil particles that usually allow faster drainage |
# | Silt | Medium-sized soil particles that hold more water than sand |
# | Clay | Very small soil particles that hold water and nutrients |
# | Organic matter | Decomposed plant and animal material in the soil |
# | pH | How acidic or alkaline the soil is |
# | Bulk density | How compacted the soil is |
# | Hydraulic conductivity | How easily water moves through saturated soil |
# | Available water storage | How much water the soil can store for plants |
# | Slope | How steep the land is |
#
# These variables may help explain why corn yield and the effects of weather
# differ between counties.

# %%
horizon_properties = {
    "sandtotal_r": "sand_pct_0_30cm",
    "silttotal_r": "silt_pct_0_30cm",
    "claytotal_r": "clay_pct_0_30cm",
    "om_r": "organic_matter_pct_0_30cm",
    "ph1to1h2o_r": "ph_0_30cm",
    "dbthirdbar_r": "bulk_density_g_cm3_0_30cm",
    "ksat_r": "ksat_um_s_0_30cm"
}

# %% [markdown]
# ## Calculate One Soil Row per County
#
# For sand, silt, clay, organic matter, pH, bulk density, and hydraulic
# conductivity, the county average is calculated as:
#
# $$
# \text{county average}
# =
# \frac{
# \sum(\text{soil value} \times \text{soil weight})
# }{
# \sum(\text{soil weight})
# }
# $$
#
# Rows missing a particular property are ignored only for that property.
#
# Available water storage and slope are already summarized by NRCS at the map-unit
# level. They are therefore weighted only by the number of map-unit acres inside
# the county.

# %%
county_soil_results = []

for fips, county_data in soil_raw_df.groupby("fips"):
    county_result = {"fips": fips}

    for original_column, final_column in horizon_properties.items():
        usable_data = county_data.dropna(subset=[original_column, "soil_weight"])
        total_weight = usable_data["soil_weight"].sum()

        if total_weight > 0:
            weighted_value = (usable_data[original_column] * usable_data["soil_weight"]).sum() / total_weight

        else:
            weighted_value = np.nan

        county_result[final_column] = weighted_value

    
    mapunit_data = (county_data.drop_duplicates("mukey").copy())

    usable_aws = mapunit_data.dropna(subset=["aws0100wta", "county_mapunit_acres"])

    if len(usable_aws) > 0:
        county_result["available_water_storage_cm_0_100cm"] = np.average(usable_aws["aws0100wta"], weights=usable_aws["county_mapunit_acres"])

    else:
        county_result["available_water_storage_cm_0_100cm"] = np.nan

    usable_slope = mapunit_data.dropna(subset=["slopegradwta", "county_mapunit_acres"])

    if len(usable_slope) > 0:
        county_result["slope_pct"] = np.average(usable_slope["slopegradwta"], weights=usable_slope["county_mapunit_acres"])

    else:
        county_result["slope_pct"] = np.nan

    county_soil_results.append(county_result)

# %% [markdown]
# ## Create final soil Dataframe

# %%
soil_df = pd.DataFrame(county_soil_results)

# %%
soil_df.to_csv('corn_belt_soil.csv', index=False)

# %%
soil_df.head()
# Out:
#     fips  sand_pct_0_30cm  silt_pct_0_30cm  clay_pct_0_30cm  \
# 0  17001         9.761685        66.093087        24.145839
# 1  17003        14.200159        60.170257        25.629584
# 2  17005        12.001764        67.758068        20.240168
# 3  17007        14.919208        62.206710        22.800581
# 4  17009        10.585626        66.772594        22.641780
#
#    organic_matter_pct_0_30cm  ph_0_30cm  bulk_density_g_cm3_0_30cm  \
# 0                   1.965400   6.272974                   1.392362
# 1                   1.916471   6.198012                   1.372761
# 2                   1.713029   6.137333                   1.405465
# 3                   3.879057   6.458088                   1.350217
# 4                   1.654722   6.189540                   1.411360
#
#    ksat_um_s_0_30cm  available_water_storage_cm_0_100cm  slope_pct
# 0          7.827496                           18.455786   6.672519
# 1         10.448577                           17.100846   9.697656
# 2          7.060548                           17.364135   4.503059
# 3         11.356888                           18.413318   2.278609
# 4          8.372990                           18.366319  13.094994

# %% [markdown]
# ---

# %%
soil_df.shape
# Out:
# (1124, 10)

# %% [markdown]
# ## Merge with Corn Yield and Weather Data

# %%
yield_weather_df["fips"] = (yield_weather_df["fips"].astype(str).str.zfill(5))

soil_df["fips"] = (soil_df["fips"].astype(str).str.zfill(5))

grand_final_df = yield_weather_df.merge(soil_df, on="fips", how="left", validate="many_to_one")

# %%
grand_final_df.head()
# Out:
#   state_name state_alpha  state_ansi  county_ansi   fips county_name  year  \
# 0   ILLINOIS          IL          17           11  17011      BUREAU  2025
# 1   ILLINOIS          IL          17           11  17011      BUREAU  2024
# 2   ILLINOIS          IL          17           11  17011      BUREAU  2023
# 3   ILLINOIS          IL          17           11  17011      BUREAU  2022
# 4   ILLINOIS          IL          17           11  17011      BUREAU  2021
#
#                                    short_desc  unit_desc statisticcat_desc  \
# 0  CORN, GRAIN - YIELD, MEASURED IN BU / ACRE  BU / ACRE             YIELD
# 1  CORN, GRAIN - YIELD, MEASURED IN BU / ACRE  BU / ACRE             YIELD
# 2  CORN, GRAIN - YIELD, MEASURED IN BU / ACRE  BU / ACRE             YIELD
# 3  CORN, GRAIN - YIELD, MEASURED IN BU / ACRE  BU / ACRE             YIELD
# 4  CORN, GRAIN - YIELD, MEASURED IN BU / ACRE  BU / ACRE             YIELD
#
#    ...  vp_mean_pa_m12  sand_pct_0_30cm  silt_pct_0_30cm  clay_pct_0_30cm  \
# 0  ...      357.549355        12.944472        62.969536        23.948762
# 1  ...      462.975000        12.944472        62.969536        23.948762
# 2  ...      614.017097        12.944472        62.969536        23.948762
# 3  ...      393.786774        12.944472        62.969536        23.948762
# 4  ...      504.136452        12.944472        62.969536        23.948762
#
#    organic_matter_pct_0_30cm  ph_0_30cm  bulk_density_g_cm3_0_30cm  \
# 0                   3.691334   6.516119                   1.363566
# 1                   3.691334   6.516119                   1.363566
# 2                   3.691334   6.516119                   1.363566
# 3                   3.691334   6.516119                   1.363566
# 4                   3.691334   6.516119                   1.363566
#
#    ksat_um_s_0_30cm  available_water_storage_cm_0_100cm  slope_pct
# 0         11.164841                           18.336345   4.666624
# 1         11.164841                           18.336345   4.666624
# 2         11.164841                           18.336345   4.666624
# 3         11.164841                           18.336345   4.666624
# 4         11.164841                           18.336345   4.666624
#
# [5 rows x 106 columns]

# %% [markdown]
# ## Save to CSV

# %%
grand_final_df.to_csv('corn_belt_yield_weather_soil.csv', index=False)
